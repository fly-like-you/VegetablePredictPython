# %%
import json

# %%
with open("../data/othSite_prediction_from_2023-05-27.json", 'rb') as f:
    oth24 = json.load(f)

# %%
with open("../data/othSite_prediction_from_2023-05-25.json", 'rb') as f:
    oth25 = json.load(f)

# %%
oth24
# Out:
# {'2023-05-16': {'실제가격': 8271,
#   '1일전 예측가격': 0,
#   '2일전 예측가격': 0,
#   '3일전 예측가격': 0,
#   '4일전 예측가격': 0,
#   '5일전 예측가격': 0,
#   '6일전 예측가격': 0,
#   '7일전 예측가격': 0},
#  '2023-05-17': {'실제가격': 6297,
#   '1일전 예측가격': 7164,
#   '2일전 예측가격': 0,
#   '3일전 예측가격': 0,
#   '4일전 예측가격': 0,
#   '5일전 예측가격': 0,
#   '6일전 예측가격': 0,
#   '7일전 예측가격': 0},
#  '2023-05-18': {'실제가격': 5255,
#   '1일전 예측가격': 8439,
#   '2일전 예측가격': 7842,
#   '3일전 예측가격': 0,
#   '4일전 예측가격': 0,
#   '5일전 예측가격': 0,
#   '6일전 예측가격': 0,
#   '7일전 예측가격': 0},
#  '2023-05-19': {'실제가격': 6696,
#   '1일전 예측가격': 5398,
#   '2일전 예측가격': 7710,
#   '3일전 예측가격': 8372,
#   '4일전 예측가격': 0,
#   '5일전 예측가격': 0,
#   '6일전 예측가격': 0,
#   '7일전 예측가격': 0},
#  '2023-05-20': {'실제가격': 7062,
#   '1일전 예측가격': 4989,
#   '2일전 예측가격': 5130,
#   '3일전 예측가격': 6628,
#   '4일전 예측가격': 6993,
#   '5일전 예측가격': 0,
#   '6일전 예측가격': 0,
#   '7일전 예측가격': 0},
#  '2023-05-21': {'실제가격': 0,
#   '1일전 예측가격': 7382,
#   '2일전 예측가격': 4900,
#   '3일전 예측가격': 5425,
#   '4일전 예측가격': 6274,
#   '5일전 예측가격': 5847,
# ...

# %%
oth24
# Out:
# {'2023-05-19': {'실제가격': 6696,
#   '1일전 예측가격': 0,
#   '2일전 예측가격': 0,
#   '3일전 예측가격': 0,
#   '4일전 예측가격': 0,
#   '5일전 예측가격': 0,
#   '6일전 예측가격': 0,
#   '7일전 예측가격': 0},
#  '2023-05-20': {'실제가격': 7062,
#   '1일전 예측가격': 4989,
#   '2일전 예측가격': 0,
#   '3일전 예측가격': 0,
#   '4일전 예측가격': 0,
#   '5일전 예측가격': 0,
#   '6일전 예측가격': 0,
#   '7일전 예측가격': 0},
#  '2023-05-21': {'실제가격': 0,
#   '1일전 예측가격': 7382,
#   '2일전 예측가격': 4900,
#   '3일전 예측가격': 0,
#   '4일전 예측가격': 0,
#   '5일전 예측가격': 0,
#   '6일전 예측가격': 0,
#   '7일전 예측가격': 0},
#  '2023-05-22': {'실제가격': 6683,
#   '1일전 예측가격': 6892,
#   '2일전 예측가격': 7359,
#   '3일전 예측가격': 5262,
#   '4일전 예측가격': 0,
#   '5일전 예측가격': 0,
#   '6일전 예측가격': 0,
#   '7일전 예측가격': 0},
#  '2023-05-23': {'실제가격': 6139,
#   '1일전 예측가격': 7160,
#   '2일전 예측가격': 7427,
#   '3일전 예측가격': 7973,
#   '4일전 예측가격': 5935,
#   '5일전 예측가격': 0,
#   '6일전 예측가격': 0,
#   '7일전 예측가격': 0},
#  '2023-05-24': {'실제가격': 5847,
#   '1일전 예측가격': 7242,
#   '2일전 예측가격': 7690,
#   '3일전 예측가격': 8062,
#   '4일전 예측가격': 8251,
#   '5일전 예측가격': 6996,
# ...

# %%
oth25
# Out:
# {'2023-05-17': {'실제가격': 6297,
#   '1일전 예측가격': 0,
#   '2일전 예측가격': 0,
#   '3일전 예측가격': 0,
#   '4일전 예측가격': 0,
#   '5일전 예측가격': 0,
#   '6일전 예측가격': 0,
#   '7일전 예측가격': 0},
#  '2023-05-18': {'실제가격': 5255,
#   '1일전 예측가격': 8439,
#   '2일전 예측가격': 0,
#   '3일전 예측가격': 0,
#   '4일전 예측가격': 0,
#   '5일전 예측가격': 0,
#   '6일전 예측가격': 0,
#   '7일전 예측가격': 0},
#  '2023-05-19': {'실제가격': 6696,
#   '1일전 예측가격': 5398,
#   '2일전 예측가격': 7710,
#   '3일전 예측가격': 0,
#   '4일전 예측가격': 0,
#   '5일전 예측가격': 0,
#   '6일전 예측가격': 0,
#   '7일전 예측가격': 0},
#  '2023-05-20': {'실제가격': 7062,
#   '1일전 예측가격': 4989,
#   '2일전 예측가격': 5130,
#   '3일전 예측가격': 6628,
#   '4일전 예측가격': 0,
#   '5일전 예측가격': 0,
#   '6일전 예측가격': 0,
#   '7일전 예측가격': 0},
#  '2023-05-21': {'실제가격': 0,
#   '1일전 예측가격': 7382,
#   '2일전 예측가격': 4900,
#   '3일전 예측가격': 5425,
#   '4일전 예측가격': 6274,
#   '5일전 예측가격': 0,
#   '6일전 예측가격': 0,
#   '7일전 예측가격': 0},
#  '2023-05-22': {'실제가격': 6683,
#   '1일전 예측가격': 6892,
#   '2일전 예측가격': 7359,
#   '3일전 예측가격': 5262,
#   '4일전 예측가격': 5943,
#   '5일전 예측가격': 6400,
# ...
